# %%
from keras.models import model_from_json
import numpy as np
from keras.preprocessing import image

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("model.weights.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
def classify_and_plot(img_file):
    if os.path.exists(img_file):  # Check if the file exists
        test_image = image.load_img(img_file, target_size=(64, 64))
        test_image_array = image.img_to_array(test_image)
        test_image_array = np.expand_dims(test_image_array, axis=0)
        result = loaded_model.predict(test_image_array)

        plt.imshow(test_image)
        plt.axis('off')

        if result[0][0] >= 0.5:
            prediction = 'thanos'
        else:
            prediction = 'kratos'

        plt.title(f"Prediction: {prediction}")
        plt.show()
    else:
        print(f"File not found: {img_file}")

# Classify and plot each image
for f in files:
    classify_and_plot(f)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# File not found: /content/dataset/test/000015.jpg
# File not found: /content/dataset/test/000018.jpg
# File not found: /content/dataset/test/000017.jpg
# File not found: /content/dataset/test/000010.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# File not found: /content/dataset/test/000016.jpg
# File not found: /content/dataset/test/000012.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# File not found: /content/dataset/test/000019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# File not found: /content/dataset/test/000011.jpg
# File not found: /content/dataset/test/000020.jpg
